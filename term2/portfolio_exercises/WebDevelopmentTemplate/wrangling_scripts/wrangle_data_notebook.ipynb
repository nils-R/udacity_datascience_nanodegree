# %%
import pandas as pd

# %%
listings = pd.read_csv('../data/detailed-stockholm-listings.csv')
reviews = pd.read_csv('../data/detailed-stockholm-reviews.csv')
calendar = pd.read_csv('../data/detailed-stockholm-calendar.csv')
neighbourhoods = pd.read_csv('../data/stockholm-neighbourhoods.csv') 
geo = pd.read_json('../data/stockholm-neighbourhoods.geojson')

# %%
df = reviews.merge(listings, left_on='listing_id', right_on='id', how='left')

# %%
reviews
# Out:
#        listing_id         id        date  reviewer_id reviewer_name  \
# 0           35664    1518738  2012-06-19      1677854         Maria
# 1           35664    1692316  2012-07-12       958739         Naomi
# 2           35664    1789023  2012-07-24      2596768      Victoria
# 3           35664    1872993  2012-08-02       827306        Jackie
# 4           35664    1916669  2012-08-07      1219569          Erin
# 5           35664    2001085  2012-08-16      2064164         Laura
# 6           35664    2028383  2012-08-19      2594319       Barbara
# 7           35664    2099495  2012-08-26      2070710           Tom
# 8           35664    2256697  2012-09-10      3458061     Alexandra
# 9           35664    2395524  2012-09-24      3092259         Maria
# 10          35664    2620467  2012-10-15      1724786          Luke
# 11          35664    2676298  2012-10-21      3840082          Adam
# 12          35664    2723204  2012-10-26      3663514         Paula
# ...
